","Small-eye Smooth-hound","Small-fin Catshark","Small-fin Gulper Shark","Smalltail Shark","Smalltooth Sand Tiger","Smalltooth Sawfish","Smooth Hammerhead","Smooth Lanternshark","Smooth-tooth Blacktip shark","Smoothback Angelshark","Snaggletooth Shark","Sombre Catshark","South China Catshark","Southern Lanternshark","Southern Mandarin Dogfish","Southern Sawtail Catshark","Southern Sleeper Shark","Spadenose Shark","Sparsetooth Dogfish","Speartooth Shark","Speckled Carpet Shark","Speckled Catshark","Speckled Smooth-hound","Speckled Swellshark","Spined Pygmy Shark","Spinner shark","Spiny Dogfish","Splendid Lanternshark","Sponge-head Catshark","Spot-tail Shark","Spotless Catshark","Spotless Smooth-hound","Spotted Estuary Smooth-hound","Spotted Houndshark","Spotted Wobbegong","Springer’s Sawtail Catshark","Starry Catshark","Starry Smooth-hound","Starspotted Smooth-hound","Stout Catshark","Straight-tooth weasel shark","Striped Smooth-hound","Swellshark","Tailspot Lanternshark","Taiwan Angelshark","Taiwan Saddled Carpetshark","Tall-light Shark","Tasselled Wobbegong","Tawny Nurse Shark","Thorny Lanternshark","Tiger Catshark","Tiger Shark","Triton Epaulette Shark","Tropical Sawshark","Variegated Catshark","Velvet Belly Lanternshark","Velvet Catshark","Velvet Dogfish","Viper Dogfish","West Indian Lanternshark","Western African catshark","Western Angelshark","Western Gulper Shark","Western Highfin Spurdog","Western Longnose Spurdog","Western Spotted Catshark","Western Wobbegong","Whale Shark","Whiskery Shark","White Ghost Catshark","White-bodied Catshark","White-clasper Catshark","White-fin Swellshark","White-margin Fin Houndshark","White-saddled Catshark","White-spotted Bamboo Shark","White-Spotted Catshark","White-spotted Smooth-hound","White-tail Dogfish","White-tip Catshark","White-tip Reef Shark","Whitecheek Shark","Whitefin Dogfish","Whitefin Topeshark","Whitenose Shark","Whitespotted Bullhead Shark","Whitetip Weasel Shark","Winghead Shark","Yellowspotted Catshark","Zebra Bullhead Shark","Zebra Shark"]

# url to shark attack file
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"
df = pd.read_excel(url)

# %%
# Function to match and correct species
def correct_species(species, reference_list, threshold=80):
    corrected_species = ""
    corrected = process.extractOne(species, reference_list)  # Get the best match
    if corrected:  # Check if result is not None
        match, score, _ = corrected
        if score >= threshold:  # Only accept matches above the threshold
            corrected_species = match
        else:
            corrected_species = species  # No good match found
    else:
        corrected_species = species  # No match found at all
    return corrected_species

# Function to keep only allowed words in the string
def filter_string(input_string, allowed_words):
    # Create a regular expression pattern to match allowed words
    pattern = '|'.join(re.escape(word) for word in allowed_words)
    # Replace everything that is not in the allowed list with an empty string
    result = ' '.join(re.findall(pattern, input_string))
    return result

def country_check(country):
    return "Yes" if country in country_name else "No"

def invalid(Type): #define function
    if Type in ["Invalid", "Watercraft", "Sea Disaster", "Questionable", "Boat","?", "Unconfirmed", "Unverified", "Under investigation"]:
        return "Invalid"
    else:
        return Type

def convert_age(Age):
    try:
        # Handle specific categories
        if Age in ['60+', '60s', 'Elderly', "60's"]:
            return 65
        elif Age in ['Middle age', '50s', 'middle-age', '"middle-age"', '>50']:
            return 55
        elif Age in ['40s']:
            return 45
        elif Age in ['30s', 'mid-30s']:
            return 35
        elif Age in ['20s', "20's", 'mid-20s', '20/30', 'adult', '20?']:
            return 25
        elif Age in ['(adult)']:
            return 18
        elif Age in ['teen', 'Teen', 'Teens', 'a minor', 'young', '"young"']:
            return 15
        elif Age == 'Both 11':
            return 11
        elif Age == '6½':
            return 6
        elif Age == '2½':
            return 2
        elif Age in ['18 months', '9 months']:
            return 1

        # Handle ranges and multiple values
        elif isinstance(Age, str) and ('to' in Age or '&' in Age or 'or' in Age or ',' in Age):
            # Replace delimiters with spaces
            for symbol in ['to', '&', 'or', ',']:
                Age = Age.replace(symbol, ' ')
            # Extract numeric parts
            parts = Age.split()
            numbers = [float(part) for part in parts if part.isdigit()]
            if numbers:
                return numbers[0]  # Return the first number

        # Handle invalid entries
        elif Age in ['?', '!2', '!!', '!6', 'M', '45 and 15', '\xa0 ', 'Ca. 33',
                     'MAKE LINE GREEN', 'F', 'X', '  ', 'A.M.', '22, 57, 31', '28,']:
            return float('nan')

        # Handle any remaining strings
        elif isinstance(Age, str):
            Age = Age.strip()  # Remove leading/trailing whitespace
            if Age.isdigit():
                return float(Age)  # Convert valid numbers to float
            else:
                return float('nan')  # Return NaN for unrecognized strings

        # Return numeric values as-is
        else:
            return float(Age)
    except ValueError:
        return float('nan')  # Fallback for unexpected issues

# %%
# modify columns
df.columns = df.columns.map(lambda col: col.lower().strip())
df.columns = df.columns.map(lambda col: col.replace(" ", "_"))
df = df.rename(columns={"fatal_y/n": "fatal"})
df = df.drop_duplicates()
df = df.dropna(how='all')
df = df.drop(columns=['date', 'year', 'state', 'location', 'name', 'injury', 'time', 'source', 'pdf', 'href_formula', 'href', 'case_number', 'case_number.1', 'original_order', 'unnamed:_21','unnamed:_22'])

# %%
# unify fatality
df.fatal = df.fatal.apply(lambda x: str(x).lower().strip())
df.fatal = df.fatal.apply(lambda x: "y" if x=="yes" or x=="y" or x=="f" else "n" if x=="n" or x=="no" else "unknown")
# unify species with fuzzy
df['species'] = df['species'].apply(lambda x: correct_species(x, reference_species))
# only allow species names to be used
df['species'] = df['species'].apply(lambda x: filter_string(str(x), reference_species))
# unify type, age, sex
df.type.fillna("unknown")
df['type']=df['type'].apply(lambda x: invalid(x))
df['age'] = df['age'].apply(lambda x: convert_age(x))
df['type'] = df['type'].replace({' Provoked': 'Provoked'})
Sex_mapping = {'F': 'F', 'M': 'M', ' M':'M', 'M ':'M', 'M x 2':'Invalid', 'N':'Invalid', 'lli':'Invalid', '.':'Invalid'}
df['sex'] = df['sex'].map(Sex_mapping)

# %%
# unify country
df["country"] = df["country"].apply(lambda x:x.upper() if isinstance(x,str) else x)
df["country"] = df["country"].apply(lambda x:x.strip() if isinstance(x,str) else x)
country_name = {country.name.upper() for country in pycountry.countries}
df["country"] = df["country"].apply(lambda x: 
                                                 "UNITED STATES" if x == "USA" else 
                                                 ("RÉUNION" if x == "REUNION" else 
                                                 ("IRAN, ISLAMIC REPUBLIC OF" if x == "IRAN" else
                                                 ("UNITED KINGDOM" if x == "ENGLAND" else
                                                 x))))
df["country"] = df["country"].apply(lambda x: 
                                                 "VIET NAM" if x == "VIETNAM" else 
                                                 ("RÉUNION" if x == "REUNION ISLAND" else 
                                                 ("RUSSIAN FEDERATION" if x == "RUSSIA" else
                                                 ("COLOMBIA" if x == "COLUMBIA" else
                                                 x))))
df["country"] = df["country"].apply(lambda x: 
                                                 "TÜRKIYE" if x == "TURKEY" else 
                                                 ("VENEZUELA, BOLIVARIAN REPUBLIC OF" if x == "VENEZUELA" else 
                                                 ("PAPUA NEW GUINEA" if x == "NEW GUINEA" else
                                                 ("TAIWAN, PROVINCE OF CHINA" if x == "TAIWAN" else
                                                 x))))
df["country"] = df["country"].apply(lambda x: 
                                                 "UNITED KINGDOM" if x == "SCOTLAND" else 
                                                 ("TANZANIA" if x == "TANZANIA" else 
                                                 ("JAPAN" if x == "OKINAWA" else
                                                 ("PORTUGAL" if x == "AZORES" else
                                                 x))))
df["country"] = df["country"].apply(lambda x: 
                                                 "TURKS AND CAICOS ISLANDS" if x == "TURKS & CAICOS" else 
                                                 ("MYANMAR" if x == "BURMA" else 
                                                 ("TRINIDAD AND TOBAGO" if x == "TRINIDAD & TOBAGO" else
                                                 ("CABO VERDE" if x == "CAPE VERDE" else
                                                 x))))
df["country"] = df["country"].apply(lambda x: 
                                                 "MALDIVES" if x == "MALDIVE ISLANDS" else 
                                                 ("SRI LANKA" if x == "CEYLON" else 
                                                 ("TRINIDAD AND TOBAGO" if x == "TOBAGO" else
                                                 ("SRI LANKA" if x == "CEYLON (SRI LANKA)" else
                                                 x))))
df["country"] = df["country"].apply(lambda x: 
                                                 "PAPUA NEW GUINEA" if x == "NEW BRITAIN" else 
                                                 ("MICRONESIA" if x == "MICRONESIA" else 
                                                 ("GREECE" if x == "CRETE" else
                                                 ("TURKS AND CAICOS ISLANDS" if x == "TURKS AND CAICOS" else
                                                 x))))
df['is_country'] = df["country"].apply(country_check)

# %%
# unify activity
df["activity"] = df["activity"].apply(lambda x:x.upper() if isinstance(x,str) else x)
df['new_activity'] = 'OTHER'
df.loc[df['activity'].str.contains('FELL', case=False, na=False), 'new_activity'] = 'FELL'
df.loc[df['activity'].str.contains('FILMING', case=False, na=False), 'new_activity'] = 'FILMING'
df.loc[df['activity'].str.contains(r'BATHING|WASHING|JUMP|WALK|STAND|SITT|PLAYING', case=False, na=False), 'new_activity'] = 'WASHING'
df.loc[df['activity'].str.contains(r'AIR', case=False, na=False), 'new_activity'] = 'RELATED TO AIRCRAFT'
df.loc[df['activity'].str.contains('FEED', case=False, na=False), 'new_activity'] = 'FEEDING ANIMALS'
df.loc[df['activity'].str.contains(r'PADDL|BOARDING', case=False, na=False), 'new_activity'] = 'PADDLE BOARDING'
df.loc[df['activity'].str.contains(r'BOAT|SHIP|YACHT|VESSEL|KAYAK|CANOE|ROW|BOARD|WRECK|ADRIF', case=False, na=False), 'new_activity'] = 'RELATED TO BOATS'
df.loc[df['activity'].str.contains('UNKNOWN', case=False, na=False), 'new_activity'] = 'UNKNOWN'
df.loc[df['activity'].str.contains('WAD', case=False, na=False), 'new_activity'] = 'WADING'
df.loc[df['activity'].str.contains('TOUCH', case=False, na=False), 'new_activity'] = 'TOUCHING SHARKS'
df.loc[df['activity'].str.contains('SURF', case=False, na=False), 'new_activity'] = 'SURFING'
df.loc[df['activity'].str.contains(r'SWIMMING|FLOATING', case=False, na=False), 'new_activity'] = 'SWIMMING'
df.loc[df['activity'].str.contains(r'DIVING|DAVE|DIVE', case=False, na=False), 'new_activity'] = 'DIVING'
df.loc[df['activity'].str.contains(r'FISH|CATCH|LOBST', case=False, na=False), 'new_activity'] = 'FISHING'
df['new_activity_1'] = np.where(df['new_activity'] == 'OTHER', df['activity'], df['new_activity'])

# %%
# hypthesis 1
species_variety = df.groupby('country')['species'].nunique().reset_index()
species_variety = species_variety.sort_values(by="species", ascending=False)
species_variety = species_variety.head(10)


# Create the histogram
plt.figure(figsize=(10, 6))  # Adjust the size of the figure
plt.title('Variety of Shark Species by Location', fontsize=14)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Unique Shark Species', fontsize=12)
plt.xticks(rotation=45)
plt.bar(species_variety['country'], species_variety['species'], color='skyblue', edgecolor='black')
#plt.hist(ages, bins=range(0, 101, 10), color='skyblue', edgecolor='black')  # Set the bins from 0 to 100 with a step of 10
plt.title('Variety of Shark Species by Location', fontsize=14)

# Display the plot
plt.tight_layout()  # Ensures everything fits well in the figure
plt.show()

# %%
# extra hypothesis
country_attacks = df.groupby('country')['fatal'].count()
sorted_country_attacks = country_attacks.sort_values(ascending=False)
top_10_countries = sorted_country_attacks.head(10)
top_10_countries_df = top_10_countries.reset_index()
top_10_countries_df.columns = ['Country', 'Attack_Count']

# Create a bar chart
plt.figure(figsize=(10, 6))  # Adjust the size of the figure
plt.bar(top_10_countries_df['Country'], top_10_countries_df['Attack_Count'], color='skyblue', edgecolor='black')
# Add titles and labels
plt.title('Top 10 Countries with the Most Attacks')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
# Rotate the labels of the countries for better readability
plt.xticks(rotation=45)
# Display the plot
plt.tight_layout()  # Ensures everything fits well in the figure
plt.show()

# %%
# hypothesis 2
activity_counts = df.groupby('new_activity_1')['fatal'].count()
sorted_activity_counts = activity_counts.sort_values(ascending=False)
top_10_activities = sorted_activity_counts.head(10)
top_10_activities_df = top_10_activities.reset_index()
top_10_activities_df.columns = ['Activity', 'Attack_Count']

plt.figure(figsize=(10, 6))  # Adjust the size of the figure
plt.bar(top_10_activities_df['Activity'], top_10_activities_df['Attack_Count'], color='skyblue', edgecolor='black')
# Add titles and labels
plt.title('Top 10 Activities with the Most Attacks')
plt.xlabel('Activity')
plt.ylabel('Number of Attacks')
# Rotate the labels of the activities for better readability
plt.xticks(rotation=45)
# Display the plot
plt.tight_layout()  # Ensures everything fits well in the figure
plt.show()

# %%
# hypothesis 3
df_provoked = df[(df['type']=='Provoked')]
# Assuming 'fatality_counts' already contains the grouped data by 'sex'
fatality_counts = df_provoked.groupby(['sex','fatal']).size().unstack()
fatality_counts = fatality_counts [['n', 'y']]
fatality_counts['total'] = fatality_counts.sum(axis=1)

# Sort the Series in descending order
fatality_counts = fatality_counts.sort_values(by='total', ascending=False)
fatality_counts = fatality_counts.drop(columns='total')

# Create a bar chart using matplotlib with sorted data
fatality_counts.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], edgecolor='black', figsize=(10, 6))

# Add titles and labels
plt.title('Provoked Attacks broken down by Sex and Type')
plt.xlabel('Sex')
plt.ylabel('Number of Fatalities')
plt.xticks(rotation=0)  # Optionally rotate the x-axis labels for better visibility

# Display the plot
plt.tight_layout()
plt.show()

# %%
top_10_countrys = df['country'].value_counts().head(10).index
df_top_10_countrys = df[df['country'].isin(top_10_countrys)]
df['fatal_rate'] = df['fatal'].apply(lambda x: 1 if x == 'y' else 0)
df_filt_sex = df_top_10_countrys[df_top_10_countrys['sex'].isin(['F', 'M'])]
resu_1 = df_filt_sex.groupby(['country', 'sex'])['fatal_rate'].agg(['mean'])
resu_1

resu_1 = resu_1.reset_index()
# Plot using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=resu_1, x='country', y='mean', hue='sex')
# Customize the plot
plt.title('Mean Fatality Rate by Country and Sex')
plt.xticks(rotation=45)
plt.ylabel('Mean Fatality Rate')
plt.xlabel('Country')
plt.legend(title='Sex')
plt.tight_layout()
# Show the plot
plt.show()

top_10_activity_1 = df['new_activity_1'].value_counts().head(10).index
df_top_10_activity_1 = df[df['new_activity_1'].isin(top_10_activity_1)]
df_filt_sex_2 = df_top_10_activity_1[df_top_10_activity_1['sex'].isin(['F', 'M'])]
resu_2 = df_filt_sex_2.groupby(['new_activity_1', 'sex'])['fatal_rate'].agg(['mean'])
resu_2

resu_2 = resu_2.reset_index()
# Plot using seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=resu_2, x='new_activity_1', y='mean', hue='sex')
# Customize the plot
plt.title('Mean Fatality Rate by Activity and Sex')
plt.xticks(rotation=45)
plt.ylabel('Mean Fatality Rate')
plt.xlabel('Activity')
plt.legend(title='Sex')
plt.tight_layout()
# Show the plot
plt.show()

df_filtered_type = df[df['type'].isin(['Provoked', 'Unprovoked'])]
# Further filter by 'sex' to include only 'M' and 'F'
df_filtered_sex = df_filtered_type[df_filtered_type['sex'].isin(['M', 'F'])]
# Analyze fatality rate by sex
fatality_analysis_by_type_and_sex = df_filtered_sex.groupby(['type', 'sex'])['fatal_rate'].agg(['mean']).reset_index()
# Display the result
print(fatality_analysis_by_type_and_sex)

df_provoked = df_filtered_sex[df_filtered_sex['type'] == 'Provoked']
# Group by 'sex' and calculate the mean of 'fatal_rate'
fatality_provoked_by_sex = df_provoked.groupby('sex')['fatal_rate'].agg(['mean']).reset_index()
# Plot using seaborn
plt.figure(figsize=(8, 6))
sns.barplot(data=fatality_provoked_by_sex, x='sex', y='mean', palette="pastel")
# Customize the plot
plt.title('Mean Fatality Rate of Provoked Attacks by Sex')
plt.ylabel('Mean Fatality Rate')
plt.xlabel('Sex')
plt.tight_layout()
# Show the plot
plt.show()
# Out:
#          type sex      mean
# 0    Provoked   F  0.032258
# 1    Provoked   M  0.032847
# 2  Unprovoked   F  0.167164
# 3  Unprovoked   M  0.253015
# /var/folders/gq/19wnck6n1lggc_91r4nzbjk80000gn/T/ipykernel_2107/2864303052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=fatality_provoked_by_sex, x='sex', y='mean', palette="pastel")
